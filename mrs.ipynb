# %%
import numpy as np
import pandas as pd 
import math
import sys
import csv

# %%
pk = pd.read_csv("pokemon.csv")

# %%
pk = pk.drop_duplicates(subset='id')

# %%
pk.reset_index()
# Out:
#      index   id                 Name   Type_1  Type_2  Total   HP  Attack  \
# 0        0    1            Bulbasaur    Grass  Poison    318   45      49
# 1        1    2              Ivysaur    Grass  Poison    405   60      62
# 2        2    3             Venusaur    Grass  Poison    525   80      82
# 3        4    4           Charmander     Fire     NaN    309   39      52
# 4        5    5           Charmeleon     Fire     NaN    405   58      64
# ..     ...  ...                  ...      ...     ...    ...  ...     ...
# 716    793  717              Yveltal     Dark  Flying    680  126     131
# 717    794  718     Zygarde50% Forme   Dragon  Ground    600  108     100
# 718    795  719              Diancie     Rock   Fairy    600   50     100
# 719    797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 720    799  721            Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# ...

# %%
def putfirst(df, i):
    return df.iloc[(np.arange(len(df)) != i).argsort()]

# %%
df = pk[pk['Name'].str.contains('Rayquaza')]
print(df.id)
# Out:
# 425    384
# Name: id, dtype: int64

# %%
pk['Type_1'].value_counts()
# Out:
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Fire         47
# Psychic      47
# Rock         41
# Electric     36
# Ground       30
# Poison       28
# Dark         28
# Fighting     25
# Dragon       24
# Ghost        23
# Ice          23
# Steel        22
# Fairy        17
# Flying        3
# Name: Type_1, dtype: int64

# %%
stat = pd.DataFrame(pk[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']])

# %%
stat
# Out:
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0     45      49       49       65       65     45
# 1     60      62       63       80       80     60
# 2     80      82       83      100      100     80
# 4     39      52       43       60       50     65
# 5     58      64       58       80       65     80
# ..   ...     ...      ...      ...      ...    ...
# 793  126     131       95      131       98     99
# 794  108     100      121       81       95     95
# 795   50     100      150      100      150     50
# 797   80     110       60      150      130     70
# 799   80     110      120      130       90     70
#
# [721 rows x 6 columns]

# %%
def cal_distance(x):      
    a = x.to_numpy()
    b = stat.to_numpy()    
    distance = math.sqrt(sum([(a - b) ** 2 for a, b in zip(a, b[0])]))
    return distance

# %%
pk['distance'] = pk[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].apply(cal_distance,args=df.id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/aijaz/Documents/py stuff/MANIT-code-master (1)/MANIT-code-master/pokemon/mrs.ipynb Cell 11 in 1
# ----> <a href='vscode-notebook-cell:/home/aijaz/Documents/py%20stuff/MANIT-code-master%20%281%29/MANIT-code-master/pokemon/mrs.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> pk['distance'] = pk[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].apply(cal_distance,args=df.id)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:9549, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9410 """
#    9411 Apply a function along an axis of the DataFrame.
#    9412
#    (...)
#    9545 2  1  2
#    9546 """
#    9547 from pandas.core.apply import frame_apply
# -> 9549 op = frame_apply(
#    9550     self,
#    9551     func=func,
#    9552     axis=axis,
#    9553     raw=raw,
# ...

# %%
pk_sort = pk.sort_values('distance',ascending=True)

# %%
pk_after_sort = pk_sort

# %%
pk_after_sort.reset_index()
# Out:
#      index   id                Name   Type_1  Type_2  Total   HP  Attack  \
# 0        0    1           Bulbasaur    Grass  Poison    318   45      49
# 1      643  582           Vanillite      Ice     NaN    305   36      50
# 2      438  393              Piplup    Water     NaN    314   53      51
# 3      762  692           Clauncher    Water     NaN    330   50      53
# 4      294  271              Lombre    Water   Grass    340   60      50
# ..     ...  ...                 ...      ...     ...    ...  ...     ...
# 716    428  386  DeoxysNormal Forme  Psychic     NaN    600   50     150
# 717    313  289             Slaking   Normal     NaN    670  150     160
# 718    121  113             Chansey   Normal     NaN    450  250       5
# 719    261  242             Blissey   Normal     NaN    540  255      10
# 720    230  213             Shuckle      Bug    Rock    505   20      10
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# ...

# %%
pk_after_sort.iloc[1]
# Out:
# id                  582
# Name          Vanillite
# Type_1              Ice
# Type_2              NaN
# Total               305
# HP                   36
# Attack               50
# Defense              50
# Sp. Atk              65
# Sp. Def              60
# Speed                44
# Generation            5
# Legendary         False
# img_scr             NaN
# distance      10.440307
# Name: 643, dtype: object
